# %% [markdown]
# Types of Regression
#
#
# Linear,
#  Multiple,
#  Polynomial,
#  Ridge,
#  Multinomial,
#  Laso

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('insurance.csv')
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df1=df.copy()
df1["smoker"]=df1["smoker"].replace({"yes":1,"no":0})
df1["sex"]=df1["sex"].replace({"female":1,"male":0})
print(df1.head())
#df.head()
# Out:
#    age  sex   bmi  children  smoker     region  expenses
# 0   19    1  27.9         0       1  southwest  16884.92
# 1   18    0  33.8         1       0  southeast   1725.55
# 2   28    0  33.0         3       0  southeast   4449.46
# 3   33    0  22.7         0       0  northwest  21984.47
# 4   32    0  28.9         0       0  northwest   3866.86

# %%
df1["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
y=df1.iloc[:,-1].values
x=df1.iloc[:,:-2].values
# Out:
# array([[19. ,  1. , 27.9,  0. ,  1. ],
#        [18. ,  0. , 33.8,  1. ,  0. ],
#        [28. ,  0. , 33. ,  3. ,  0. ],
#        ...,
#        [18. ,  1. , 36.9,  0. ,  0. ],
#        [21. ,  1. , 25.8,  0. ,  0. ],
#        [61. ,  1. , 29.1,  0. ,  1. ]])

# %%
import seaborn as sns
sns.pairplot(df)

# %%
#splitting the dataset into training set and test set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y, test_size=0.2,random_state=11)
print(f'Shape of training set= {X_train.shape}')
print(f'Shape of testing set= {X_test.shape}')
# Out:
# Shape of training set= (1070, 5)
# Shape of testing set= (268, 5)

# %%
#fitting
from sklearn.linear_model import LinearRegression
babu=LinearRegression()
babu.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Now our equation is defined
c=babu.coef_
i=babu.intercept_
print(c,i)
# Out:
# [  264.52568266   401.47267289   327.93955799   540.55974196
#  23533.75748347] -12769.548222924132

# %%
#Predict
y_pred = babu.predict(X_test)
#y_pred

# %%
babu.score(X_test,y_test)
# Out:
# 0.7989382227343123

# %%
#accuracy Matrix
from sklearn.metrics import mean_squared_error,r2_score
rmse=(np.sqrt(mean_squared_error(y1_test, y1_pred)))
r2score=r2_score(y1_test, y1_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34320\1078812210.py in <module>
#       1 #accuracy Matrix
#       2 from sklearn.metrics import mean_squared_error,r2_score
# ----> 3 rmse=(np.sqrt(mean_squared_error(y1_test, y1_pred)))
#       4 r2score=r2_score(y1_test, y1_pred)
#
# NameError: name 'y1_test' is not defined
